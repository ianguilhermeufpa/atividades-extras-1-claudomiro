# %% [markdown]
# ### Contar quantos bits seriam necessários para determinados níveis de quantização
#
# Professor, adicionei essa função pra verificar se o número é aceito, pois precisa ser uma potencia de 2.

# %%
numeroNiveis = int(input())
numeroBits = 0 
contagem = 1

def potencia(numero):
    while numero % 2 == 0:
        numero = numero // 2
    if numero != 1:
        return False
    else:
        return True

if potencia(numeroNiveis) == False:
    print("Numero de níveis inválido!")
else:
    for n in range(int(numeroNiveis)):
        print(bin(contagem)[2:])
        contagem += 1

    while numeroNiveis != 1:
        numeroNiveis = numeroNiveis / 2
        numeroBits += 1


    print("NUMERO DE BITS: ", numeroBits)
